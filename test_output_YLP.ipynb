# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GOOGLE_COLAB/LRCN
# !git clone -b update1 https://github.com/TrinhNguyen02/YoloV7_Pose_estimate_and_Tracking.git
# %cd /content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6-pose.pt
# Out:
# /content/drive/MyDrive/GOOGLE_COLAB/LRCN
# fatal: destination path 'YoloV7_Pose_estimate_and_Tracking' already exists and is not an empty directory.
# --2023-04-08 05:36:13--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6-pose.pt
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking
# !python pose_cp.py smoking
# Out:
# /content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking
# Process accion: VIDEOS_50_120 ...
# /content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking/Data_YLP/smoking
# ['smoking', 'normalaction', 'standing_up']
# Process accion: normalaction ...
# []
# Process accion: smoking ...
# []
# --Procesando: a041-0414C.mp4
# a041-0414C
# Fusing layers...
# Frame 0 Processing
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Objects in Current Frame : 1
# Frame 1 Processing
# Objects in Current Frame : 1
# Frame 2 Processing
# Objects in Current Frame : 1
# Frame 3 Processing
# Objects in Current Frame : 1
# Frame 4 Processing
# Objects in Current Frame : 1
# Frame 5 Processing
# ...

# %%
# %cd /content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking
# !python pose-estimate.py --device gpu --source /content/drive/MyDrive/GOOGLE_COLAB/LRCN/LRCN_OP_YOLO/datos/NTURGBD/VIDEOS_50_120/smoking/a041-0414C.mp4
# Out:
# /content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking
# Optimizer stripped from yolov7-w6-pose.pt, 161.1MB
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking/pose-estimate.py", line 205, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking/pose-estimate.py", line 200, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking/pose-estimate.py", line 53, in run
#     device = select_device(opt.device) #select device
#   File "/content/drive/MyDrive/GOOGLE_COLAB/LRCN/YoloV7_Pose_estimate_and_Tracking/utils/torch_utils.py", line 71, in select_device
# ...
